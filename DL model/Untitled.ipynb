# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
drive_log=pd.read_csv("train2/drive.csv")

# %%
drive_log.iloc[0]['loc']
# Out:
# '/home/ashwin/Downloads/IMG/center_2021_03_24_16_19_33_446.jpg'

# %%
img=cv2.imread(drive_log.iloc[0]['loc'])

# %%
plt.imshow(img)
